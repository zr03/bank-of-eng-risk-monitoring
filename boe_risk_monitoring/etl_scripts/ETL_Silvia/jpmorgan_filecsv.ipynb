# %%
import pandas as pd

# %%
file_list=["1Q21_Earnings_Supplement.xlsx","2Q21_Earnings_Supplement.xlsx","3Q21_Earnings_Supplement.xlsx","4Q21_Earnings_Supplement.xlsx",
           "1q22-earnings-supplement.xlsx","2Q22-Earnings-Supplement.xlsx","3Q22_Earnings_Supplement.xlsx","4q22-earnings-supplement-xls.xlsx",
           "1q23-earnings-supplement.xlsx","2q23-earnings-supplement.xlsx","3q23-earnings-supplement.xlsx","4q23-earnings-supplement.xlsx",
           "1Q24_Earnings_Supplement.xlsx","2q24-earnings-supplement.xlsx","3q24-earnings-supplement.xlsx","4q24-earnings-supplement.xlsx",
          "1q25-earnings-supplement.xlsx" ]

# %%
def data_extraction_jpmorgan(file_list,sheet_name):
  df_list = []
  quarters=[]
  for item in file_list:
    df_page2 = pd.read_excel(item, sheet_name=sheet_name, header=None, usecols="B:F", skiprows=6)
    header_rows = df_page2.iloc[1:4, 1:5]
    col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
    quarter_label = df_page2.iloc[0, 4]
    final_columns = ['Quarters'] + [f"{quarter_label} - {h}" for h in col_header]
    line_items = df_page2.iloc[2:39, 0:3].apply(lambda row: ' '.join(row.dropna().astype(str)).strip(), axis=1)
    data_values = df_page2.iloc[2:39, 4]
    data_values_cleaned = data_values.replace(r'\((.*?)\)', r'-\1', regex=True).astype(str).str.replace(',', '').str.replace('$', '', regex=False).str.replace('%', '', regex=False).str.strip()
    data_values_numeric = pd.to_numeric(data_values_cleaned, errors='coerce')
    df_list.append(data_values_numeric)
    quarters.append(final_columns[1][:4])

  lista=pd.DataFrame(df_list)
  lista.columns=line_items
  lista.index=quarters
  df_results=lista.dropna(axis=1)
  df_results.head()
  return df_results

# %%
df_results=data_extraction_jpmorgan(file_list,"Page 2")
# Out:
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_values_cleaned = data_values.replace(r'\((.*?)\)', r'-\1', regex=True).astype(str).str.replace(',', '').str.replace('$', '', regex=False).str.replace('%', '', regex=False).str.strip()
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_values_cleaned = data_values.replace(r'\((.*?)\)', r'-\1', regex=True).astype(str).str.replace(',', '').str.replace('$', '', regex=False).str.replace('%', '', regex=False).str.strip()
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_values_cleaned = data_values.replace(r'\((.*?)\)', r'-\1', regex=True).astype(str).str.replace(',', '').str.replace('$', '', regex=False).str.replace('%', '', regex=False).str.strip()
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_values_cleaned = data_values.replace(r'\((.*?)\)', r'-\1', regex=True).astype(str).str.replace(',', '').str.replace('$', '', regex=False).str.replace('%', '', regex=False).str.strip()
# <ipython-input-10-1733553387>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   col_header = header_rows.fillna(method='ffill', axis=1).apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-10-1733553387>:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_values_cleaned = data_values.replace(r'\((.*?)\)', r'-\1', regex=True).astype(str).str.replace(',', '').str.replace('$', '', regex=False).str.replace('%', '', regex=False).str.strip()

# %%
df_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 1Q21 to 1Q25
# Data columns (total 27 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Total net revenue                                17 non-null     float64
#  1   Total noninterest expense                        17 non-null     float64
#  2   Pre-provision profit (a)                         17 non-null     float64
#  3   Provision for credit losses                      17 non-null     float64
#  4   NET INCOME                                       17 non-null     float64
#  5   Total net revenue                                17 non-null     float64
#  6   Total noninterest expense                        17 non-null     float64
#  7   Pre-provision profit (a)                         17 non-null     float64
#  8   Provision for credit losses                      17 non-null     float64
#  9   NET INCOME                                       17 non-null     float64
#  10  Net income: Basic                                17 non-null     float64
#  11  Diluted                                          17 non-null     float64
#  12  Average shares: Basic                            17 non-null     float64
#  13  Diluted                                          17 non-null     float64
#  14  Market capitalization                            17 non-null     float64
#  15  Common shares at period-end                      17 non-null     float64
#  16  Book value per share                             17 non-null     float64
#  17  Tangible book value per share (“TBVPS”) (a)      17 non-null     float64
#  18  Cash dividends declared per share                17 non-null     float64
#  19  Return on common equity (“ROE”)                  17 non-null     float64
#  20  Return on tangible common equity (“ROTCE”) (a)   17 non-null     float64
#  21  Return on assets                                 17 non-null     float64
#  22  Common equity Tier 1 (“CET1”) capital ratio (e)  17 non-null     float64
#  23  Tier 1 capital ratio (e)                         17 non-null     float64
#  24  Total capital ratio (e)                          17 non-null     float64
#  25  Tier 1 leverage ratio                            17 non-null     float64
#  26  Supplementary leverage ratio (“SLR”)             17 non-null     float64
# dtypes: float64(27)
# memory usage: 3.7+ KB

# %%
df_results.head()
# Out:
#       Total net revenue  Total noninterest expense  Pre-provision profit (a)  \
# 1Q21            32266.0                    18725.0                   13541.0
# 2Q21            30479.0                    17667.0                   12812.0
# 3Q21            29647.0                    17063.0                   12584.0
# 4Q21            29257.0                    17888.0                   11369.0
# 1Q22            30717.0                    19191.0                   11526.0
#
#       Provision for credit losses  NET INCOME  Total net revenue  \
# 1Q21                      -4156.0     14300.0            33119.0
# 2Q21                      -2285.0     11948.0            31395.0
# 3Q21                      -1527.0     11687.0            30441.0
# 4Q21                      -1288.0     10399.0            30349.0
# 1Q22                       1463.0      8282.0            31590.0
#
#       Total noninterest expense  Pre-provision profit (a)  \
# 1Q21                    18725.0                   14394.0
# 2Q21                    17667.0                   13728.0
# 3Q21                    17063.0                   13378.0
# 4Q21                    17888.0                   12461.0
# 1Q22                    19191.0                   12399.0
#
#       Provision for credit losses  NET INCOME  ...  \
# 1Q21                      -4156.0     14300.0  ...
# 2Q21                      -2285.0     11948.0  ...
# 3Q21                      -1527.0     11687.0  ...
# 4Q21                      -1288.0     10399.0  ...
# 1Q22                       1463.0      8282.0  ...
#
#       Tangible book value per share (“TBVPS”) (a)  \
# 1Q21                                        66.56
# 2Q21                                        68.91
# 3Q21                                        69.87
# 4Q21                                        71.53
# 1Q22                                        69.58
#
#       Cash dividends declared per share  Return on common equity (“ROE”)  \
# 1Q21                                0.9                             23.0
# 2Q21                                0.9                             18.0
# 3Q21                                1.0                             18.0
# 4Q21                                1.0                             16.0
# 1Q22                                1.0                             13.0
#
#       Return on tangible common equity (“ROTCE”) (a)  Return on assets  \
# 1Q21                                            29.0              1.61
# 2Q21                                            23.0              1.29
# 3Q21                                            22.0              1.24
# 4Q21                                            19.0              1.08
# 1Q22                                            16.0              0.86
#
#       Common equity Tier 1 (“CET1”) capital ratio (e)  \
# 1Q21                                             13.1
# 2Q21                                             13.0
# 3Q21                                             12.9
# 4Q21                                             13.0
# 1Q22                                             11.9
#
#       Tier 1 capital ratio (e)  Total capital ratio (e)  \
# 1Q21                      15.0                     17.2
# 2Q21                      15.1                     17.1
# 3Q21                      15.0                     16.9
# 4Q21                      15.0                     16.8
# 1Q22                      13.7                     15.4
#
#       Tier 1 leverage ratio  Supplementary leverage ratio (“SLR”)
# 1Q21                    6.7                                   6.7
# 2Q21                    6.6                                   5.4
# 3Q21                    6.6                                   5.5
# 4Q21                    6.5                                   5.4
# 1Q22                    6.2                                   5.2
#
# [5 rows x 27 columns]

# %%
df_results.to_csv("jpmorgan_cleaned_summary.csv", index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4142436624> in <cell line: 0>()
# ----> 1 df_results.to_csv("jpmorgan_cleaned_summary.csv", index=True)
#
# NameError: name 'df_results' is not defined

# %%
df_results.to_excel("jpmorgan_cleaned_summary.xlsx", index=True)
